# %%
import pandas as pd
df = pd.read_csv('Sample_Superstore(Final).csv') 
df_cleaned = df.drop_duplicates(subset=['Order ID', 'Product ID'], keep='first')
print("DataFrame after removing duplicates:")
print(df_cleaned)
# Out:
# DataFrame after removing duplicates:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   12/6/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  11/10/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  11/10/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    4/5/2017    9/5/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df_cleaned = df.drop_duplicates(subset=['Order ID', 'Product ID'], keep='first')

# %%
duplicate_count = df_cleaned.duplicated(subset=['Order ID', 'Product ID']).sum()

print(f"Number of duplicate pairs remaining: {duplicate_count}")
if duplicate_count == 0:
    print(" There are absolutely no duplicate values left.")
else:
    print(" There are still some duplicates in the data.")
# Out:
# Number of duplicate pairs remaining: 0
#  There are absolutely no duplicate values left.

# %%
import pandas as pd
df = pd.read_csv('Sample_Superstore(Final).csv') 
print(df['City'].unique())
# Out:
# ['Henderson' 'Los Angeles' 'Fort Lauderdale' 'Concord' 'Seattle'
#  'Fort Worth' 'Madison' 'West Jordan' 'San Francisco' 'Fremont'
#  'Philadelphia' 'Orem' 'Houston' 'Richardson' 'Naperville' 'Melbourne'
#  'Eagan' 'Westland' 'Dover' 'New Albany' 'New York City' 'Troy' 'Chicago'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Portland' 'Saint Paul' 'Aurora' 'Charlotte'
#  'Orland Park' 'Urbandale' 'Columbus' 'Bristol' 'Wilmington' 'Bloomington'
#  'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Newark' 'Franklin'
#  'Scottsdale' 'San Jose' 'Edmond' 'Carlsbad' 'San Antonio' 'Monroe'
#  'Fairfield' 'Grand Prairie' 'Redlands' 'Hamilton' 'Westfield' 'Akron'
#  'Denver' 'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit'
#  'Tampa' 'Santa Clara' 'Lakeville' 'San Diego' 'Brentwood' 'Chapel Hill'
#  'Morristown' 'Cincinnati' 'Inglewood' 'Tamarac' 'Colorado Springs'
# ...

# %%
df['Region'] = df['Region'].str.strip()
df['City'] = df['City'].str.strip()

# %%
df['Region'] = df['Region'].str.title()
df['City'] = df['City'].str.title()

# %%
city_mapping = {
    "Nyc": "New York City",
    "La": "Los Angeles",
    "Sfo": "San Francisco"
}
df['City'] = df['City'].replace(city_mapping)

# %%
df['City'] = df['City'].fillna('Unknown')

# %%
print(df['City'].unique())
# Out:
# ['Henderson' 'Los Angeles' 'Fort Lauderdale' 'Concord' 'Seattle'
#  'Fort Worth' 'Madison' 'West Jordan' 'San Francisco' 'Fremont'
#  'Philadelphia' 'Orem' 'Houston' 'Richardson' 'Naperville' 'Melbourne'
#  'Eagan' 'Westland' 'Dover' 'New Albany' 'New York City' 'Troy' 'Chicago'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Portland' 'Saint Paul' 'Aurora' 'Charlotte'
#  'Orland Park' 'Urbandale' 'Columbus' 'Bristol' 'Wilmington' 'Bloomington'
#  'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Newark' 'Franklin'
#  'Scottsdale' 'San Jose' 'Edmond' 'Carlsbad' 'San Antonio' 'Monroe'
#  'Fairfield' 'Grand Prairie' 'Redlands' 'Hamilton' 'Westfield' 'Akron'
#  'Denver' 'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit'
#  'Tampa' 'Santa Clara' 'Lakeville' 'San Diego' 'Brentwood' 'Chapel Hill'
#  'Morristown' 'Cincinnati' 'Inglewood' 'Tamarac' 'Colorado Springs'
# ...

# %%
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')
df['Profit'] = pd.to_numeric(df['Profit'], errors='coerce')

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Sales'] = df['Sales'].astype(float)

# %%
import datetime
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# %%
import openpyxl
import  pyarrow

# %%
print(df['City'].unique())
# Out:
# ['Henderson' 'Los Angeles' 'Fort Lauderdale' 'Concord' 'Seattle'
#  'Fort Worth' 'Madison' 'West Jordan' 'San Francisco' 'Fremont'
#  'Philadelphia' 'Orem' 'Houston' 'Richardson' 'Naperville' 'Melbourne'
#  'Eagan' 'Westland' 'Dover' 'New Albany' 'New York City' 'Troy' 'Chicago'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Portland' 'Saint Paul' 'Aurora' 'Charlotte'
#  'Orland Park' 'Urbandale' 'Columbus' 'Bristol' 'Wilmington' 'Bloomington'
#  'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Newark' 'Franklin'
#  'Scottsdale' 'San Jose' 'Edmond' 'Carlsbad' 'San Antonio' 'Monroe'
#  'Fairfield' 'Grand Prairie' 'Redlands' 'Hamilton' 'Westfield' 'Akron'
#  'Denver' 'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit'
#  'Tampa' 'Santa Clara' 'Lakeville' 'San Diego' 'Brentwood' 'Chapel Hill'
#  'Morristown' 'Cincinnati' 'Inglewood' 'Tamarac' 'Colorado Springs'
# ...

# %%
df = pd.read_csv("superstore_20260610_173405.csv")
df["Profit"] = (
    df["Profit"]
    .astype(str)
    .str.replace(r"[$,]", "", regex=True)
)

df["Profit"] = pd.to_numeric(df["Profit"], errors="coerce")

df = df.drop_duplicates()

df = df.dropna(subset=["Region", "City", "Sales", "Profit"])

df.to_csv("superstore_cleaned.csv", index=False)

df.to_parquet(
    "superstore_cleaned.parquet",
    index=False,
    engine="pyarrow"
)

print("Cleaning completed successfully!")
print("CSV File: superstore_cleaned.csv")
print("Parquet File: superstore_cleaned.parquet")
# Out:
# Cleaning completed successfully!
# CSV File: superstore_cleaned.csv
# Parquet File: superstore_cleaned.parquet

# %%
import pandas as pd
df = pd.read_parquet("superstore_cleaned.parquet")
print(df.head(10))
print(df.info())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-08-11  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-08-11  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-12-06   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  2015-11-10  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-11-10  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812  2014-09-06   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812  2014-09-06   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812  2014-09-06   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812  2014-09-06   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812  2014-09-06   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
df["Ship Date"] = pd.to_datetime(df["Ship Date"]).dt.strftime("%Y/%m/%d")
df.to_csv("superstore_cleaned.csv", index=False)
print(df["Ship Date"].head())
# Out:
# 0    2016/11/11
# 1    2016/11/11
# 2    2016/06/16
# 3    2015/10/18
# 4    2015/10/18
# Name: Ship Date, dtype: object

# %%
import pandas as pd

# Load the cleaned superstore data
df = pd.read_csv('superstore_cleaned.csv')

# 1. Standardize date strings to YYYY-MM-DD format so SQL parses them correctly
df['Order Date'] = pd.to_datetime(df['Order Date'].str.replace('/', '-')).dt.strftime('%Y-%m-%d')
df['Ship Date'] = pd.to_datetime(df['Ship Date'].str.replace('/', '-')).dt.strftime('%Y-%m-%d')

# 2. Optionally ensure that postal codes are padded strings if you want to retain leading zeros
# df['Postal Code'] = df['Postal Code'].astype(str).str.zfill(5)

# Save out to a database-ready file
df.to_csv('superstore_sql_ready.csv', index=False)

# %%
df = pd.read_csv("superstore_cleaned.csv")
print(df.head(10))
print(df.info())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-08-11  2016/11/11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-08-11  2016/11/11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-12-06  2016/06/16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-11-10  2015/10/18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-11-10  2015/10/18  Standard Class    SO-20335
# 5       6  CA-2014-115812  2014-09-06  2014/06/14  Standard Class    BH-11710
# 6       7  CA-2014-115812  2014-09-06  2014/06/14  Standard Class    BH-11710
# 7       8  CA-2014-115812  2014-09-06  2014/06/14  Standard Class    BH-11710
# 8       9  CA-2014-115812  2014-09-06  2014/06/14  Standard Class    BH-11710
# 9      10  CA-2014-115812  2014-09-06  2014/06/14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('superstore_cleaned.csv')

# Convert the 'object' columns to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

print(df[['Order Date', 'Ship Date']].dtypes)
# Out:
# Order Date    datetime64[ns]
# Ship Date     datetime64[ns]
# dtype: object

# %%
df = pd.read_csv("superstore_cleaned.csv")
print(df.head(10))
print(df.info())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-08-11  2016/11/11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-08-11  2016/11/11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-12-06  2016/06/16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-11-10  2015/10/18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-11-10  2015/10/18  Standard Class    SO-20335
# 5       6  CA-2014-115812  2014-09-06  2014/06/14  Standard Class    BH-11710
# 6       7  CA-2014-115812  2014-09-06  2014/06/14  Standard Class    BH-11710
# 7       8  CA-2014-115812  2014-09-06  2014/06/14  Standard Class    BH-11710
# 8       9  CA-2014-115812  2014-09-06  2014/06/14  Standard Class    BH-11710
# 9      10  CA-2014-115812  2014-09-06  2014/06/14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
# Convert the date columns to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# Verify the changes
print(df[['Order Date', 'Ship Date']].dtypes)
print("\n", df[['Order Date', 'Ship Date']].head())
# Out:
# Order Date    datetime64[ns]
# Ship Date     datetime64[ns]
# dtype: object
#
#    Order Date  Ship Date
# 0 2016-08-11 2016-11-11
# 1 2016-08-11 2016-11-11
# 2 2016-12-06 2016-06-16
# 3 2015-11-10 2015-10-18
# 4 2015-11-10 2015-10-18

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine


engine = create_engine('mysql+pymysql://root:Lokesh%40556477@DB_HOST/zenith_retail')

query = """
WITH customer_spend AS (
    SELECT 
        `Customer ID`,
        `Customer Name`,
        ROUND(SUM(Sales), 2)       AS Total_Spend,
        COUNT(DISTINCT `Order ID`) AS Total_Orders,
        ROUND(SUM(Profit), 2)      AS Total_Profit,
        ROUND(AVG(Sales), 2)       AS Avg_Order_Value
    FROM zenith_retail.orders
    GROUP BY `Customer ID`, `Customer Name`
),
ntile_ranking AS (
    SELECT *,
        NTILE(10) OVER (ORDER BY Total_Spend DESC) AS Spend_Tile
    FROM customer_spend
)
SELECT 
    `Customer ID`,
    `Customer Name`,
    Total_Spend,
    Total_Orders,
    Total_Profit,
    Avg_Order_Value,
    'VIP Customer' AS Customer_Segment
FROM ntile_ranking
WHERE Spend_Tile = 1
ORDER BY Total_Spend DESC
"""

df = pd.read_sql(query, engine)
df.to_csv('./', index=False)
print(f"✅ {len(df)} VIP Customers exported!")
print(df.head(10))
# Out:
# ✅ 80 VIP Customers exported!
#   Customer ID       Customer Name  Total_Spend  Total_Orders  Total_Profit  \
# 0    SM-20320         Sean Miller     25043.05             5      -1980.74
# 1    TC-20980        Tamara Chand     19052.22             5       8981.32
# 2    RB-19360        Raymond Buch     15117.34             6       6976.10
# 3    TA-21385        Tom Ashbrook     14595.62             4       4703.79
# 4    AB-10105       Adrian Barton     14473.57            10       5444.81
# 5    KL-16645        Ken Lonsdale     14175.23            12        806.86
# 6    SC-20095        Sanjit Chand     14142.33             9       5757.41
# 7    HL-15040        Hunter Lopez     12873.30             6       5622.43
# 8    SE-20110        Sanjit Engle     12209.44            11       2650.68
# 9    CC-12370  Christopher Conant     12129.07             5       2177.05
#
#    Avg_Order_Value Customer_Segment
# 0          1669.54     VIP Customer
# 1          1587.68     VIP Customer
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://username:password@DB_HOST/zenith_retail')

# All tables and views to export
exports = [
    'orders',
    'products',
    'superstore_formatted',
    'vw_monthly_revenue',
    'vw_category_rankings',
    'vw_vip_customers',
    'vw_low_inventory_alert',
    'vw_declining_margins'
]

for table in exports:
    df = pd.read_sql(f'SELECT * FROM zenith_retail.{table}', engine)
    path = f'./'
    df.to_csv(path, index=False)
    print(f"✅ {table}: {len(df)} records exported → {path}")

print("\n🎉 All files exported successfully!")
# Out:
# ✅ orders: 9994 records exported → ./
# ✅ products: 1862 records exported → ./
# ✅ superstore_formatted: 9994 records exported → ./
# ✅ vw_monthly_revenue: 48 records exported → ./
# ✅ vw_category_rankings: 3 records exported → ./
# ✅ vw_vip_customers: 793 records exported → ./
# ✅ vw_low_inventory_alert: 932 records exported → ./
# ✅ vw_declining_margins: 132 records exported → ./
#
# 🎉 All files exported successfully!
